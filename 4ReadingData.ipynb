# %%
##   Reading Data from Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '{"employee_name": "James", "email": "james@gmail.com", "job_profile": [{"titel": "team lead", "title2": "Sr. Developer"}]}'
pd.read_json(StringIO(Data))
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'titel': 'team lead', 'title2': 'Sr. Developer'}

# %%
df
# Out:
#               0         1       2   \
# 0    PassengerId  Survived  Pclass
# 1              1         0       3
# 2              2         1       1
# 3              3         1       3
# 4              4         1       1
# ..           ...       ...     ...
# 887          887         0       2
# 888          888         1       1
# 889          889         0       3
# 890          890         1       1
# 891          891         0       3
#
#                                                     3       4    5      6   \
# 0                                                 Name     Sex  Age  SibSp
# 1                              Braund, Mr. Owen Harris    male   22      1
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                               Heikkinen, Miss. Laina  female   26      0
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# ..                                                 ...     ...  ...    ...
# ...

# %%
# df.to_json()

# %%
# df.to_json(orient='index')

# %%
# df.to_json(orient='records')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv', header=None )

# %%
df.head()
# Out:
#             0         1       2   \
# 0  PassengerId  Survived  Pclass
# 1            1         0       3
# 2            2         1       1
# 3            3         1       3
# 4            4         1       1
#
#                                                   3       4    5      6   \
# 0                                               Name     Sex  Age  SibSp
# 1                            Braund, Mr. Owen Harris    male   22      1
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 3                             Heikkinen, Miss. Laina  female   26      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
#
#       7                 8        9      10        11
# 0  Parch            Ticket     Fare  Cabin  Embarked
# 1      0         A/5 21171     7.25    NaN         S
# 2      0          PC 17599  71.2833    C85         C
# 3      0  STON/O2. 3101282    7.925    NaN         S
# 4      0            113803     53.1   C123         S

# %%
df.to_csv('sales_data.csv')

# %%
## pip install beautifulsoup4 lxml html5lib

## read html url
# url = 'https://www.fdic.gov/'

# df= pd.read_csv(url)

## Explore this oon the chatgpt

# %%
## Excel file
df_excel = pd.read_excel('Book1.xlsx')

# %%
df_excel.to_pickle('df_excel.pkl')

# %%
dff=pd.read_pickle('df_excel.pkl')

# %%
dff
# Out:
# Empty DataFrame
# Columns: []
# Index: []
